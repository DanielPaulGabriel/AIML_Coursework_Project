# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

data1 = pd.read_csv("Concrete_Data.csv",header=0, skipinitialspace=True)
data1.dropna(inplace=True)
data = data1[(data1 != 0).all(axis=1)]

zero_counts = (data == 0).sum()
print("Count of zero values in each column:")
print(zero_counts)
# Out:
# Count of zero values in each column:
# Cement (component 1)(kg in a m^3 mixture)                0
# Blast Furnace Slag (component 2)(kg in a m^3 mixture)    0
# Fly Ash (component 3)(kg in a m^3 mixture)               0
# Water  (component 4)(kg in a m^3 mixture)                0
# Superplasticizer (component 5)(kg in a m^3 mixture)      0
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)     0
# Fine Aggregate (component 7)(kg in a m^3 mixture)        0
# Age (day)                                                0
# Concrete compressive strength(MPa, megapascals)          0
# dtype: int64

# %%
data.describe()
# Out:
#        Cement (component 1)(kg in a m^3 mixture)  \
# count                                 225.000000
# mean                                  250.212000
# std                                   106.433393
# min                                   132.000000
# 25%                                   167.000000
# 50%                                   213.800000
# 75%                                   314.000000
# max                                   491.000000
#
#        Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# count                                         225.000000
# mean                                           86.445778
# std                                            58.340748
# min                                            11.000000
# 25%                                            24.000000
# 50%                                            97.000000
# 75%                                           129.900000
# max                                           214.000000
#
#        Fly Ash (component 3)(kg in a m^3 mixture)  \
# count                                  225.000000
# mean                                   117.048000
# std                                     38.543678
# min                                     24.500000
# 25%                                     94.000000
# 50%                                    122.000000
# 75%                                    141.000000
# max                                    195.000000
#
#        Water  (component 4)(kg in a m^3 mixture)  \
# count                                 225.000000
# mean                                  176.358222
# std                                    21.302834
# min                                   121.800000
# 25%                                   162.000000
# 50%                                   175.100000
# 75%                                   190.600000
# max                                   247.000000
#
#        Superplasticizer (component 5)(kg in a m^3 mixture)  \
# count                                         225.000000
# mean                                            8.820444
# std                                             3.466515
# min                                             1.700000
# 25%                                             6.500000
# 50%                                             8.400000
# 75%                                            10.900000
# max                                            22.100000
#
#        Coarse Aggregate  (component 6)(kg in a m^3 mixture)  \
# count                                         225.000000
# mean                                          946.156000
# std                                            78.637377
# min                                           814.000000
# 25%                                           879.600000
# 50%                                           942.000000
# 75%                                          1006.300000
# max                                          1080.800000
#
#        Fine Aggregate (component 7)(kg in a m^3 mixture)   Age (day)  \
# count                                         225.000000  225.000000
# mean                                          755.316889   31.071111
# std                                            58.366609   23.754404
# min                                           612.000000    3.000000
# 25%                                           712.000000   14.000000
# 50%                                           764.400000   28.000000
# 75%                                           793.500000   28.000000
# max                                           880.000000  100.000000
#
#        Concrete compressive strength(MPa, megapascals)
# count                                        225.000000
# mean                                          38.302044
# std                                           14.220164
# min                                            7.320000
# 25%                                           28.630000
# 50%                                           36.440000
# 75%                                           48.670000
# max                                           76.240000

# %%
data.head(5)
# Out:
#      Cement (component 1)(kg in a m^3 mixture)  \
# 224                                      168.0
# 225                                      168.0
# 226                                      168.0
# 227                                      168.0
# 228                                      168.0
#
#      Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 224                                               42.1
# 225                                               42.1
# 226                                               42.1
# 227                                               42.1
# 228                                               42.1
#
#      Fly Ash (component 3)(kg in a m^3 mixture)  \
# 224                                       163.8
# 225                                       163.8
# 226                                       163.8
# 227                                       163.8
# 228                                       163.8
#
#      Water  (component 4)(kg in a m^3 mixture)  \
# 224                                      121.8
# 225                                      121.8
# 226                                      121.8
# 227                                      121.8
# 228                                      121.8
#
#      Superplasticizer (component 5)(kg in a m^3 mixture)  \
# 224                                                5.7
# 225                                                5.7
# 226                                                5.7
# 227                                                5.7
# 228                                                5.7
#
#      Coarse Aggregate  (component 6)(kg in a m^3 mixture)  \
# 224                                             1058.7
# 225                                             1058.7
# 226                                             1058.7
# 227                                             1058.7
# 228                                             1058.7
#
#      Fine Aggregate (component 7)(kg in a m^3 mixture)  Age (day)  \
# 224                                              780.1          3
# 225                                              780.1         14
# 226                                              780.1         28
# 227                                              780.1         56
# 228                                              780.1        100
#
#      Concrete compressive strength(MPa, megapascals)
# 224                                              7.75
# 225                                             17.82
# 226                                             24.24
# 227                                             32.85
# 228                                             39.23

# %%
Y = data['Concrete compressive strength(MPa, megapascals) ']
X = data.drop(['Concrete compressive strength(MPa, megapascals) '],axis = 1)
print(X.shape)
print(Y.shape)
# Out:
# (225, 8)
# (225,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


lin_reg = LinearRegression(normalize=True)
lin_reg.fit(X_train_scaled,y_train)
# Out:
# LinearRegression(normalize=True)

# %%
Y_pred = lin_reg.predict(X_test_scaled)

r2_value = r2_score(y_test, Y_pred)


print("Coefficients: ", lin_reg.coef_)
print("Intercept: ", lin_reg.intercept_)


print('R-squared Coefficient of determination: %.2f'
      # %r2_value)
# Out:
# Coefficients:  [11.55046312  7.22277124  1.50555734 -1.16393692  0.98132138  1.86181695
#   2.95299484  8.98746715]
# Intercept:  37.919388888888896
# R-squared Coefficient of determination: 0.71

# %%
df = pd.DataFrame({'Actual':y_test,'Predicted':Y_pred,'Diff(%)':((y_test - Y_pred) / y_test) * 100})
print(df)
# Out:
#       Actual  Predicted     Diff(%)
# 233    53.90  61.508215  -14.115427
# 930    30.88  35.615348  -15.334677
# 509    72.10  46.057623   36.119802
# 987    33.76  40.962395  -21.334108
# 838    27.68  35.012469  -26.490133
# 1001   53.52  39.652449   25.910970
# 928    24.58  29.180117  -18.714878
# 475    35.36  40.015282  -13.165390
# 924    26.97  34.563351  -28.154806
# 920    29.07  34.738413  -19.499185
# 446    53.72  44.839937   16.530274
# 289     7.32  19.228637 -162.686299
# 970    46.23  46.012631    0.470190
# 354    30.45  34.289328  -12.608632
# 359    27.42  28.118024   -2.545674
# 400    67.87  49.392448   27.224918
# 426    29.55  27.323848    7.533511
# 922    33.80  35.260366   -4.320608
# 490    34.77  39.777308  -14.401230
# 889    33.72  35.921351   -6.528325
# 463    56.06  56.370021   -0.553017
# 292    43.50  39.078865   10.163529
# 894    29.72  30.433639   -2.401207
# 848    33.40  36.543893   -9.412852
# 485    50.24  49.895959    0.684794
# 471    57.03  49.378597   13.416453
# 948    26.23  34.773272  -32.570614
# 910    26.14  31.348995  -19.927295
# 1019   35.23  24.062734   31.698171
# 493    41.67  41.275438    0.946872
# 507    62.05  45.409656   26.817637
# 459    55.02  61.319371  -11.449239
# 290    21.50  23.348496   -8.597654
# 964    29.87  34.892383  -16.814139
# 973    26.15  31.533853  -20.588346
# 506    61.86  58.431508    5.542341
# 956    23.52  29.410933  -25.046482
# 503    59.59  59.380327    0.351859
# 500    57.92  47.944595   17.222730
# 831    16.50  26.026862  -57.738558
# 530    66.78  56.011516   16.125313
# 1000   44.61  36.396295   18.412251
# 830    33.76  40.968671  -21.352699
# 1025   44.28  41.417150    6.465334
# 829    37.17  34.097798    8.265273
